# %% [markdown]
# Contours can be explained simply as a curve joining all the continuous points (along the boundary), having same color or intensity. The contours are a useful tool for shape analysis and object detection and recognition.
# cv.findContours(), cv.drawContours()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('../Resources/Photos/park.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
imgplot = plt.imshow(img)
plt.show()

img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
imgplot = plt.imshow(img)
plt.show()
ret, thresh = cv2.threshold(img,150,255,0)
imgplot = plt.imshow(thresh)
plt.show()
contours,hierarchy = cv2.findContours(thresh, 1, 2)



area = cv2.contourArea(contours[0])
print(area)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# e:\Chiranjeev\opencv\opencv-course\image-processing\contour.ipynb Cell 2' in <cell line: 17>()
#      <a href='vscode-notebook-cell:/e%3A/Chiranjeev/opencv/opencv-course/image-processing/contour.ipynb#ch0000002?line=14'>15</a> imgplot = plt.imshow(thresh)
#      <a href='vscode-notebook-cell:/e%3A/Chiranjeev/opencv/opencv-course/image-processing/contour.ipynb#ch0000002?line=15'>16</a> plt.show()
# ---> <a href='vscode-notebook-cell:/e%3A/Chiranjeev/opencv/opencv-course/image-processing/contour.ipynb#ch0000002?line=16'>17</a> contours,hierarchy = cv2.findContours(thresh, 1, 2)
#      <a href='vscode-notebook-cell:/e%3A/Chiranjeev/opencv/opencv-course/image-processing/contour.ipynb#ch0000002?line=20'>21</a> area = cv2.contourArea(contours[0])
#      <a href='vscode-notebook-cell:/e%3A/Chiranjeev/opencv/opencv-course/image-processing/contour.ipynb#ch0000002?line=21'>22</a> print(area)
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\contours.cpp:197: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'
